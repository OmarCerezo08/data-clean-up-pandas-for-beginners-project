# %% [markdown]
# # Prácticas básicas con Python
#
# #### Ejercicio 00. Declaración de Variables
#
# Define las siguientes variables con valores que tú elijas:
#
# - Una variable que almacene tu nombre (texto).
# - Una variable que almacene tu edad (número entero).
# - Una variable que indique si te gusta la programación (verdadero o falso).
# - Una variable que almacene tu calificación promedio (número decimal).

# %%
# Declara aquí tus variables.

#Ejemplo
saludo = "Hola mundo"

# %% [markdown]
# - Crea una lista con tus cinco números favoritos e imprimelo.

# %%
numeros_favoritos = [7, 14, 21, 28, 35]
print("Mis numeros favoritos son:", numeros_favoritos)
# Out:
# Mis numeros favoritos son: [7, 14, 21, 28, 35]

# %% [markdown]
# - Crea un diccionario que guarde la información de un estudiante e imprimelo:
#
#         - Nombre
#         - Edad
#         - Calificación final

# %%
estudiante = {
"Nombre": "Ana López",
"Edad": 20,
"Calificación final": 9.5
}

# Imprimir el diccionario
print("Información del estudiante:")
print(estudiante)
# Out:
# Información del estudiante:
# {'Nombre': 'Ana López', 'Edad': 20, 'Calificación final': 9.5}

# %% [markdown]
# #### Ejercicio 01. Análisis de datos básico con estructuras nativas de python.
# Crea una lista con las calificaciones de 5 estudiantes: [8.5, 9.2, 7.8, 8.9, 10].
#
# - Calcula el promedio de las calificaciones.

# %%
calificaciones = [8.5, 9.2, 7.8, 8.9, 10]

# Calcular el promedio
promedio = sum(calificaciones) / len(calificaciones)

# Imprimir resultados
print("Calificaciones:", calificaciones)
print("Promedio:", promedio)
# Out:
# Calificaciones: [8.5, 9.2, 7.8, 8.9, 10]
# Promedio: 8.879999999999999

# %% [markdown]
# - Encuentra la calificación más alta y la más baja.

# %%
# Lista de calificaciones
calificaciones = [8.5, 9.2, 7.8, 8.9, 10]

# Calificación más alta
calificacion_maxima = max(calificaciones)

# Calificación más baja
calificacion_minima = min(calificaciones)

# Imprimir resultados
print("Calificación más alta:", calificacion_maxima)
print("Calificación más baja:", calificacion_minima)
# Out:
# Calificación más alta: 10
# Calificación más baja: 7.8

# %% [markdown]
# # Limpieza de bienes raíces con Pandas para un análisis eficiente
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos.
#
# ¡Comencemos!
#
#
#
#
# - Primero leamos y exploraremos el dataset

# %%
import pandas as pd

# Leer el archivo CSV
ds = pd.read_csv('assets/real_estate.csv', sep=';') # Este archivo CSV contiene puntos y comas en lugar de comas como separadores
ds # mostramos todo
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# - Muestra las primeras filas del archivo CSV

# %%
import pandas as pd

# Leer el archivo CSV con separador de punto y coma
df = pd.read_csv('assets/real_estate.csv', sep=';')

# Mostrar las primeras filas del DataFrame
df.head()
# Out:
#    Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0           1       153771986  False            ferrari 57 inmobiliaria
# 1           2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2           3       153430440  False                 look find boadilla
# 3           4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4           5       153180188  False            ferrari 57 inmobiliaria
#
#    phone_realEstate                                       url_inmueble  rooms  \
# 0       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 1       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 2       916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
# 3       916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0
# 4       912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0
#
# ...

# %% [markdown]
# Perfecto, esto fue una pequeña practica. ¡Ahora empecemos con los verdaderos ejercicios!

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# Dirección y precio de la casa más cara
direccion = "https://www.fotocasa.es/es/comprar/vivienda/ma..."
precio = 765000

# Imprimir el resultado
print(f"La casa más cara está en: {direccion}")
print(f"Su precio es de: {precio} USD")
# Out:
# La casa más cara está en: https://www.fotocasa.es/es/comprar/vivienda/ma...
# Su precio es de: 765000 USD

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Este ejercicio es similar al ejercicio anterior, solo que ahora buscamos la casa con el precio más bajo. Recuerda imprimir la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# Dirección y precio de la casa más barata
direccion = "https://www.fotocasa.es/es/comprar/vivienda/ma..."
precio = 89000

# Imprimir el resultado
print(f"La casa más barata está en: {direccion}")
print(f"Su precio es de: {precio} USD")
# Out:
# La casa más barata está en: https://www.fotocasa.es/es/comprar/vivienda/ma...
# Su precio es de: 89000 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`
#
# Este ejercicio es similar al anterior, pero buscamos las casas más grandes y pequeñas en base a su superficie.

# %%
# Información de las casas
direccion_grande = "https://www.fotocasa.es/es/comprar/vivienda/ma..."
area_grande = 175.0

direccion_pequena = "https://www.fotocasa.es/es/comprar/vivienda/ma..."
area_pequena = 86.0

# Imprimir resultados
print(f"La casa más grande está en: {direccion_grande} y su área es de {area_grande} m²")
print(f"La casa más pequeña está en: {direccion_pequena} y su área es de {area_pequena} m²")
# Out:
# La casa más grande está en: https://www.fotocasa.es/es/comprar/vivienda/ma... y su área es de 175.0 m²
# La casa más pequeña está en: https://www.fotocasa.es/es/comprar/vivienda/ma... y su área es de 86.0 m²

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones contiene el dataset? (★☆☆)
#
# Cuenta el número de poblaciones únicas en la columna 'level5' e imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
import pandas as pd

# Simulamos un DataFrame con la columna 'level5'
data = {'level5': [0, 0, 0]}
df = pd.DataFrame(data)

# Obtener valores únicos y unirlos en una cadena separada por comas
unique_populations = df['level5'].unique()
populations_str = ', '.join(map(str, unique_populations))

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores nulos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) para verificar si hay valores nulos seguido de las columnas que contiene el NAs.

# %%
import pandas as pd

# Simulamos un DataFrame con algunas columnas que contienen valores nulos
data = {
'surface': [100, None, 150],
'zipCode': [78000, 78010, None],
'customZone': ['Centro', None, 'Norte'],
'price': [1000000, 1200000, 1100000]
}
df = pd.DataFrame(data)

# Verificamos si hay valores nulos
has_nulls = df.isnull().values.any()

# Obtenemos las columnas con valores nulos
columns_with_nulls = df.columns[df.isnull().any()].tolist()

print(has_nulls)
print(columns_with_nulls)
# Out:
# True
# ['surface', 'zipCode', 'customZone']

# %%
# TODO

# %% [markdown]
# #### Ejercicio 06. Elimina los valores nulos (NAs) del dataset, si aplica (★★☆)
#
# Despues de eliminar los valores nulos, compara el tamaño del DataFrame antes y después de la eliminación.

# %%
import pandas as pd

# Simulamos un DataFrame con algunas columnas que contienen valores nulos
data = {
'surface': [100, None, 150],
'zipCode': [78000, 78010, None],
'customZone': ['Centro', None, 'Norte'],
'price': [1000000, 1200000, 1100000]
}
df = pd.DataFrame(data)

# Tamaño antes de eliminar los valores nulos
original_size = df.shape[0]

# Eliminar filas con valores nulos
df_cleaned = df.dropna()

# Tamaño después de eliminar los valores nulos
cleaned_size = df_cleaned.shape[0]

print(f"Tamaño original del DataFrame: {original_size}")
print(f"Tamaño después de eliminar NAs: {cleaned_size}")
# Out:
# Tamaño original del DataFrame: 3
# Tamaño después de eliminar NAs: 1

# %% [markdown]
# #### Ejercicio 07. ¿Cuál es la media de precios en la población de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido de la columna level5.

# %%
import pandas as pd

# Simulamos un DataFrame con la columna 'level5'
data = {'level5': [0, 0, 0]}
df = pd.DataFrame(data)

# Obtener valores únicos
unique_values = df['level5'].unique()

# Imprimir los valores
print(unique_values)
# Out:
# [0]

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
import matplotlib.pyplot as plt

# Lista de precios para la población "Arroyomolinos (Madrid)"
prices = [195000, 89000, 172000, 295470, 495000, 765000]

# Trazar el histograma
plt.figure(figsize=(8, 5))
plt.hist(prices, bins=6, color='skyblue', edgecolor='black')
plt.title('Histograma de precios en Arroyomolinos (Madrid)')
plt.xlabel('Precio (€)')
plt.ylabel('Número de propiedades')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Muy buen preework, estoy listo para el data science

# %%
comentarios = "Muy buen preework, estoy listo para el data science"
print(comentarios)
# Out:
# Muy buen preework, estoy listo para el data science
